# %%
a=3# literal 리터럴 (값)
a# Reference 레퍼런스(참조) operator '=' 연산자, operand a,3
# Out:
# 3

# %%
b=7
a=b
a
# Out:
# 7

# %%
def func(x,y):
  return x+y

c=func(a,b)
c
# Out:
# 14

# %%
def func_life(x):# branch
  y=0 #스텍공간
  return x+y

d=func_life(a)

d
# Out:
# 7
