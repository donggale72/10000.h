# %% [markdown]
# <a href="https://colab.research.google.com/github/donggale72/10000.html/blob/main/cnn_fashion_mnist_classification_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 필요한 패키지를 가져옵니다.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import urllib

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.datasets import fashion_mnist

# %% [markdown]
# 패션아이템 이미지 데이터셋을 불러옵니다.

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

print('x_train shape : ' + str(x_train.shape))
print('y_train shape : ' + str(y_train.shape))
print('x_test shape : ' + str(x_test.shape))
print('y_test shape : ' + str(y_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step
# x_train shape : (60000, 28, 28)
# y_train shape : (60000,)
# x_test shape : (10000, 28, 28)
# y_test shape : (10000,)

# %% [markdown]
# 테스트할 샘플 하나를 살펴봅니다.

# %%
import matplotlib.pyplot as plt

plt.imshow(x_test[0], cmap='gray')

# %% [markdown]
# 인공지능 모델이 이 이미지를 입력받았을 때, 해당하는 숫자를 출력할 수 있도록 만드는 것이 목표입니다. 우리는 y_test 라벨값도 가지고 있어서 바로 확인은 할 수 있으나, 모델 학습 시에는 사용이 되지 않으며, 시험 평가할 때만 사용됩니다.

# %%
print(y_test[0])
# Out:
# 9

# %% [markdown]
# 패션아이템 이미지와 라벨의 숫자가 의미하는 아이템 이름과 함께 같이 가시화 시킵니다.

# %%
fig, axes = plt.subplots(nrows=10, ncols=10, figsize=(13, 15), 
                         subplot_kw={'xticks': [], 'yticks': []})

labels = ['T-shirt/top',
          'Trouser',
          'Pullover',
          'Dress',
          'Coat',
          'Sandal',
          'Shirt',
          'Sneaker',
          'Bag',
          'Ankle boot']

for i, ax in enumerate(axes.flat):
    ax.imshow(x_train[i], cmap = 'gray')
    title = labels[y_train[i]]
    ax.set_title(title)

plt.show()

# %% [markdown]
# 모델 학습에 용이하도록 다음과 같이 데이터 전처리를 수행합니다.
#
# *   데이터 전처리
#     * 3차원(샘플수, 세로, 가로)를 2차원(샘플수, 벡터수)으로 변경
#     * 정수를 실수로 변경
#     * 0 ~ 255 사이의 수치를 0.0 ~ 1.0 사이로 정규화 수행
# *   라벨 전처리
#     * 0 ~ 9 라벨에 대한 원핫인코딩 수행

# %%
x_train = x_train.reshape(60000, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(10000, 28, 28, 1).astype('float32') / 255.0
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# 모델은 다음과 같이 구성하였습니다.
#
# * 입력: 1차원의 784개 벡터
# * 출력: 10개 벡터
# * 출력층의 활성화 함수: 소프트맥스
# * 손실함수: categorical_crossentropy
# * 최적화기: adam
# * 평가 메트릭: accuracy
#
# 컨볼루션 신경망을 구성하기 위해, 컨볼루션 레이어, 맥스풀링 레이어, 플래튼 레이어를 사용하였습니다.

# %%
model = Sequential([
    Conv2D(32, (3, 3), padding='same', input_shape=(28, 28, 1), activation='relu'),
    Conv2D(32, (3, 3), padding='same', activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)), 
    Conv2D(64, (3, 3), padding='same', activation='relu'), 
    Conv2D(64, (3, 3), padding='same', activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)), 
    Flatten(), 
    Dense(512, activation='relu'), 
    Dense(10, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# 모델 네트워크 아키텍처 구성을 그려보겠습니다.

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# 모델을 학습시킬 때, validation_split 옵션을 두면 훈련셋 일부를 검증셋으로 설정할 수 있습니다. 0.2로 설정할 경우, 전체 훈련셋에서 20%를 검증셋, 나머지를 훈련셋으로 구성하여 학습합니다.
#
# 콜백함수를 사용하여, 매 에포크마다 검증셋의 손실값을 체크한 후, 이전 손실값보다 낮은 경우 모델을 파일로 저장합니다. 즉 학습 종료가 되면, "best_model.h5" 파일에 저장된 모델은 손실값이 가장 낮을 때의 가중치를 가지고 있습니다.

# %%
checkpoint_callback = ModelCheckpoint("best_model.h5", 
                                      save_best_only=True, 
                                      monitor="val_loss")

hist = model.fit(x_train, y_train, 
                 validation_split=0.2, 
                 batch_size=32,
                 epochs=100,  
                 callbacks=[checkpoint_callback])
# Out:
# Epoch 1/100
# 1500/1500 [==============================] - 20s 6ms/step - loss: 0.3869 - accuracy: 0.8595 - val_loss: 0.2659 - val_accuracy: 0.9025
# Epoch 2/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2405 - accuracy: 0.9108 - val_loss: 0.2303 - val_accuracy: 0.9154
# Epoch 3/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.1881 - accuracy: 0.9306 - val_loss: 0.2219 - val_accuracy: 0.9180
# Epoch 4/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.1539 - accuracy: 0.9419 - val_loss: 0.2205 - val_accuracy: 0.9223
# Epoch 5/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.1201 - accuracy: 0.9550 - val_loss: 0.2209 - val_accuracy: 0.9273
# Epoch 6/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0888 - accuracy: 0.9672 - val_loss: 0.2495 - val_accuracy: 0.9264
# Epoch 7/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0719 - accuracy: 0.9737 - val_loss: 0.2482 - val_accuracy: 0.9279
# Epoch 8/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0560 - accuracy: 0.9793 - val_loss: 0.2941 - val_accuracy: 0.9209
# Epoch 9/100
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.0455 - accuracy: 0.9835 - val_loss: 0.3464 - val_accuracy: 0.9242
# Epoch 10/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0390 - accuracy: 0.9860 - val_loss: 0.3564 - val_accuracy: 0.9237
# Epoch 11/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0337 - accuracy: 0.9880 - val_loss: 0.4086 - val_accuracy: 0.9283
# Epoch 12/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0296 - accuracy: 0.9892 - val_loss: 0.5256 - val_accuracy: 0.9222
# Epoch 13/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0265 - accuracy: 0.9909 - val_loss: 0.4355 - val_accuracy: 0.9262
# Epoch 14/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0269 - accuracy: 0.9908 - val_loss: 0.4731 - val_accuracy: 0.9237
# Epoch 15/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0261 - accuracy: 0.9913 - val_loss: 0.4738 - val_accuracy: 0.9212
# Epoch 16/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0246 - accuracy: 0.9922 - val_loss: 0.5035 - val_accuracy: 0.9202
# Epoch 17/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0241 - accuracy: 0.9924 - val_loss: 0.5405 - val_accuracy: 0.9229
# Epoch 18/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0228 - accuracy: 0.9925 - val_loss: 0.5228 - val_accuracy: 0.9229
# Epoch 19/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0214 - accuracy: 0.9930 - val_loss: 0.5539 - val_accuracy: 0.9191
# Epoch 20/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0239 - accuracy: 0.9921 - val_loss: 0.6092 - val_accuracy: 0.9166
# Epoch 21/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0196 - accuracy: 0.9939 - val_loss: 0.5678 - val_accuracy: 0.9213
# Epoch 22/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0197 - accuracy: 0.9941 - val_loss: 0.5410 - val_accuracy: 0.9251
# Epoch 23/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0188 - accuracy: 0.9945 - val_loss: 0.5640 - val_accuracy: 0.9243
# Epoch 24/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0204 - accuracy: 0.9935 - val_loss: 0.6213 - val_accuracy: 0.9204
# Epoch 25/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0188 - accuracy: 0.9945 - val_loss: 0.6365 - val_accuracy: 0.9242
# Epoch 26/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0170 - accuracy: 0.9951 - val_loss: 0.7094 - val_accuracy: 0.9208
# Epoch 27/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0172 - accuracy: 0.9945 - val_loss: 0.6799 - val_accuracy: 0.9219
# Epoch 28/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0227 - accuracy: 0.9940 - val_loss: 0.6041 - val_accuracy: 0.9250
# Epoch 29/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0202 - accuracy: 0.9943 - val_loss: 0.6259 - val_accuracy: 0.9212
# Epoch 30/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0148 - accuracy: 0.9958 - val_loss: 0.6803 - val_accuracy: 0.9237
# Epoch 31/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0199 - accuracy: 0.9946 - val_loss: 0.7010 - val_accuracy: 0.9232
# Epoch 32/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0151 - accuracy: 0.9960 - val_loss: 0.7765 - val_accuracy: 0.9181
# Epoch 33/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0171 - accuracy: 0.9951 - val_loss: 0.8068 - val_accuracy: 0.9204
# Epoch 34/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0178 - accuracy: 0.9950 - val_loss: 0.7014 - val_accuracy: 0.9218
# Epoch 35/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0172 - accuracy: 0.9958 - val_loss: 0.7398 - val_accuracy: 0.9222
# Epoch 36/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0189 - accuracy: 0.9950 - val_loss: 0.7668 - val_accuracy: 0.9219
# Epoch 37/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.9204 - val_accuracy: 0.9204
# Epoch 38/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0175 - accuracy: 0.9955 - val_loss: 0.8568 - val_accuracy: 0.9219
# Epoch 39/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0178 - accuracy: 0.9956 - val_loss: 0.9720 - val_accuracy: 0.9229
# Epoch 40/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0169 - accuracy: 0.9956 - val_loss: 0.9658 - val_accuracy: 0.9194
# Epoch 41/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0203 - accuracy: 0.9952 - val_loss: 0.9005 - val_accuracy: 0.9227
# Epoch 42/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0160 - accuracy: 0.9959 - val_loss: 0.9217 - val_accuracy: 0.9237
# Epoch 43/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0172 - accuracy: 0.9957 - val_loss: 0.8826 - val_accuracy: 0.9219
# Epoch 44/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0180 - accuracy: 0.9956 - val_loss: 0.9500 - val_accuracy: 0.9237
# Epoch 45/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0125 - accuracy: 0.9968 - val_loss: 1.0092 - val_accuracy: 0.9201
# Epoch 46/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0144 - accuracy: 0.9963 - val_loss: 0.9201 - val_accuracy: 0.9221
# Epoch 47/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0221 - accuracy: 0.9950 - val_loss: 0.8989 - val_accuracy: 0.9223
# Epoch 48/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0145 - accuracy: 0.9965 - val_loss: 0.9397 - val_accuracy: 0.9241
# Epoch 49/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0138 - accuracy: 0.9968 - val_loss: 1.0444 - val_accuracy: 0.9187
# Epoch 50/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0164 - accuracy: 0.9957 - val_loss: 1.0433 - val_accuracy: 0.9175
# Epoch 51/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0157 - accuracy: 0.9957 - val_loss: 1.0084 - val_accuracy: 0.9194
# Epoch 52/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0154 - accuracy: 0.9966 - val_loss: 1.0152 - val_accuracy: 0.9201
# Epoch 53/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0168 - accuracy: 0.9962 - val_loss: 1.1819 - val_accuracy: 0.9208
# Epoch 54/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0217 - accuracy: 0.9953 - val_loss: 1.0910 - val_accuracy: 0.9214
# Epoch 55/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0116 - accuracy: 0.9972 - val_loss: 1.0305 - val_accuracy: 0.9216
# Epoch 56/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0161 - accuracy: 0.9961 - val_loss: 1.0223 - val_accuracy: 0.9209
# Epoch 57/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0144 - accuracy: 0.9964 - val_loss: 1.1666 - val_accuracy: 0.9226
# Epoch 58/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0137 - accuracy: 0.9968 - val_loss: 1.0817 - val_accuracy: 0.9243
# Epoch 59/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0100 - accuracy: 0.9975 - val_loss: 1.2256 - val_accuracy: 0.9194
# Epoch 60/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0162 - accuracy: 0.9961 - val_loss: 1.1054 - val_accuracy: 0.9222
# Epoch 61/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0207 - accuracy: 0.9959 - val_loss: 1.1294 - val_accuracy: 0.9205
# Epoch 62/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0153 - accuracy: 0.9966 - val_loss: 1.0335 - val_accuracy: 0.9223
# Epoch 63/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0128 - accuracy: 0.9972 - val_loss: 1.3057 - val_accuracy: 0.9233
# Epoch 64/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0142 - accuracy: 0.9969 - val_loss: 1.0868 - val_accuracy: 0.9208
# Epoch 65/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0169 - accuracy: 0.9967 - val_loss: 1.1935 - val_accuracy: 0.9224
# Epoch 66/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0189 - accuracy: 0.9962 - val_loss: 1.2846 - val_accuracy: 0.9212
# Epoch 67/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0163 - accuracy: 0.9964 - val_loss: 1.1527 - val_accuracy: 0.9200
# Epoch 68/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0119 - accuracy: 0.9974 - val_loss: 1.4197 - val_accuracy: 0.9185
# Epoch 69/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0151 - accuracy: 0.9970 - val_loss: 1.3740 - val_accuracy: 0.9178
# Epoch 70/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0187 - accuracy: 0.9967 - val_loss: 1.2509 - val_accuracy: 0.9258
# Epoch 71/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0156 - accuracy: 0.9969 - val_loss: 1.5127 - val_accuracy: 0.9192
# Epoch 72/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0162 - accuracy: 0.9966 - val_loss: 1.5055 - val_accuracy: 0.9201
# Epoch 73/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0184 - accuracy: 0.9967 - val_loss: 1.3978 - val_accuracy: 0.9149
# Epoch 74/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0175 - accuracy: 0.9962 - val_loss: 1.5384 - val_accuracy: 0.9253
# Epoch 75/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0132 - accuracy: 0.9972 - val_loss: 1.5818 - val_accuracy: 0.9189
# Epoch 76/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0139 - accuracy: 0.9972 - val_loss: 1.5989 - val_accuracy: 0.9194
# Epoch 77/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0192 - accuracy: 0.9967 - val_loss: 1.6290 - val_accuracy: 0.9214
# Epoch 78/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0165 - accuracy: 0.9971 - val_loss: 1.5858 - val_accuracy: 0.9233
# Epoch 79/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0149 - accuracy: 0.9975 - val_loss: 1.6003 - val_accuracy: 0.9233
# Epoch 80/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0157 - accuracy: 0.9971 - val_loss: 1.4725 - val_accuracy: 0.9214
# Epoch 81/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0164 - accuracy: 0.9974 - val_loss: 1.5523 - val_accuracy: 0.9227
# Epoch 82/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0159 - accuracy: 0.9973 - val_loss: 1.5827 - val_accuracy: 0.9208
# Epoch 83/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0209 - accuracy: 0.9965 - val_loss: 1.7234 - val_accuracy: 0.9183
# Epoch 84/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0159 - accuracy: 0.9974 - val_loss: 1.7685 - val_accuracy: 0.9231
# Epoch 85/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0138 - accuracy: 0.9976 - val_loss: 1.7984 - val_accuracy: 0.9214
# Epoch 86/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0212 - accuracy: 0.9971 - val_loss: 1.8065 - val_accuracy: 0.9217
# Epoch 87/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0104 - accuracy: 0.9981 - val_loss: 1.8796 - val_accuracy: 0.9208
# Epoch 88/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0224 - accuracy: 0.9967 - val_loss: 1.7669 - val_accuracy: 0.9209
# Epoch 89/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0175 - accuracy: 0.9974 - val_loss: 1.7865 - val_accuracy: 0.9205
# Epoch 90/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0177 - accuracy: 0.9971 - val_loss: 1.8149 - val_accuracy: 0.9224
# Epoch 91/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0241 - accuracy: 0.9965 - val_loss: 1.7499 - val_accuracy: 0.9196
# Epoch 92/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0160 - accuracy: 0.9975 - val_loss: 1.9488 - val_accuracy: 0.9222
# Epoch 93/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0185 - accuracy: 0.9972 - val_loss: 1.9700 - val_accuracy: 0.9194
# Epoch 94/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0196 - accuracy: 0.9973 - val_loss: 2.0378 - val_accuracy: 0.9159
# Epoch 95/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0237 - accuracy: 0.9967 - val_loss: 2.0508 - val_accuracy: 0.9192
# Epoch 96/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0158 - accuracy: 0.9975 - val_loss: 2.1265 - val_accuracy: 0.9212
# Epoch 97/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0190 - accuracy: 0.9976 - val_loss: 2.1031 - val_accuracy: 0.9227
# Epoch 98/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0152 - accuracy: 0.9975 - val_loss: 2.0474 - val_accuracy: 0.9218
# Epoch 99/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0147 - accuracy: 0.9980 - val_loss: 2.4001 - val_accuracy: 0.9210
# Epoch 100/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0265 - accuracy: 0.9967 - val_loss: 2.2271 - val_accuracy: 0.9190

# %% [markdown]
# 학습 시 매 에포크에 해당하는 훈련셋과 검증셋에 대한 손실값과 평가 메트릭 수치를 확인할 수 있습니다. 이를 시각화시키면 어느 에포크에서 오버피팅이 일어났는 지 한 눈에 확인할 수 있습니다.

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %% [markdown]
# 파일로 저장된 모델을 로딩하여 시험셋으로 최종 평가를 수행합니다.

# %%
model = load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2405 - accuracy: 0.9151
# Test accuracy 0.9150999784469604
# Test loss 0.2404935508966446

# %% [markdown]
# 또한 시험셋으로 테스트한 결과를 제출하기 위해 모델 결과 파일을 저장합니다. 출력이 10개 클래스에 해당하는 벡터이므로, 분류한 클래스 정보를 얻기 위해 가장 높은 값을 가진 인덱스 값을 가지고 옵니다. 이 인덱스가 클래스를 의미하며, 이 값을 파일로 저장합니다.

# %%
y_pred = model.predict(x_test)
y_pred = y_pred.argmax(axis=-1)
np.savetxt('y_pred.csv', y_pred, fmt='%d')
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# #### 실제로 사용해보기

# %%
def download_real_image(filename):
    url = 'https://github.com/aifactory-team/AFClass/blob/master/aifactory/warehouse/' + filename + '?raw=true' 
    urllib.request.urlretrieve(url, filename)

def predict_from_real_image(filename, invert):
    
    f, axarr = plt.subplots(2,2, subplot_kw={'xticks': [], 'yticks': []})
    
    img = Image.open(filename)
    axarr[0,0].imshow(img)
    axarr[0,0].set_title('orgin')

    img = img.resize((28, 28), Image.LANCZOS)
    axarr[0,1].imshow(img)
    axarr[0,1].set_title('resize')

    img = img.convert('L')
    axarr[1,0].imshow(img, cmap='gray')
    axarr[1,0].set_title('gray')

    img = np.array(img)
    if invert == True:
        img = 255.0 - img
        axarr[1,1].set_title('invert')
    else:
        axarr[1,1].set_title('no invert')
        
    axarr[1,1].imshow(img, cmap='gray')

    x_predict = img.reshape(1, 28, 28, 1).astype('float32') / 255.0
    y_predict = model.predict(x_predict)
    print(y_predict)
    print(labels[np.argmax(y_predict, axis=1)[0]])

# %%
download_real_image('fashion_item_1.png')
predict_from_real_image('fashion_item_1.png', invert = True)
# Out:
# 1/1 [==============================] - 0s 139ms/step
# [[1.30408583e-02 6.09720189e-07 5.74441045e-04 7.08884545e-06
#   5.79046737e-03 3.43438296e-05 7.41919037e-03 8.11063001e-06
#   9.73114729e-01 1.02206395e-05]]
# Bag

# %%
download_real_image('fashion_item_2.png')
predict_from_real_image('fashion_item_2.png', invert=False)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# [[3.3297107e-02 4.8538893e-03 6.1633321e-04 1.7786592e-03 2.0368879e-04
#   4.2472393e-04 5.2674055e-01 3.9667837e-04 4.3059841e-01 1.0899464e-03]]
# Shirt

# %%
download_real_image('fashion_item_2.png')
predict_from_real_image('fashion_item_2.png', invert=True)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# [[1.5010130e-04 5.6257937e-07 3.8123390e-04 1.9669937e-02 9.7769439e-01
#   2.2056678e-07 2.0726016e-03 1.5566333e-05 6.6794987e-06 8.7011222e-06]]
# Coat

# %%
download_real_image('fashion_item_3.png')
predict_from_real_image('fashion_item_3.png', invert=True)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# [[3.0837045e-03 2.8416355e-06 2.7967650e-05 1.4198094e-04 2.8690087e-05
#   5.9540084e-06 9.1379037e-04 1.8297494e-04 9.9560249e-01 9.6413705e-06]]
# Bag

# %%
download_real_image('fashion_item_4.png')
predict_from_real_image('fashion_item_4.png', invert=True)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# [[1.4839038e-06 3.5428169e-08 3.2325667e-07 4.7076810e-06 1.1127469e-06
#   3.3686849e-06 5.0935699e-07 9.9602854e-01 3.7689183e-06 3.9561768e-03]]
# Sneaker
