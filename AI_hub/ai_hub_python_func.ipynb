# %%
def add(*params):#강제 언팩
  total = 0
  for i in params:
    total +=i
  return total

add(1,2,3,4,5)
# Out:
# 15

# %%
d = {'a': 1,  'b':2}
e = {'c':3}
{**d, 'c':3} # **는 키값 포함 강제 언팩
{**d, **e}
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
def add(a, b):
  return a+b

params = {'a':1, 'b':20}
add(**params)
# Out:
# 21

# %%
def add(**kwargs):
  print(kwargs)

add(a= 3, b=4)# 딕셔너리로 바꾸어줌

d={'e':1, 'f':2}
add(**d) # 강제로 묵어줌
# Out:
# {'a': 3, 'b': 4}
# {'e': 1, 'f': 2}

# %%
def add(a, b): # 1번 방식
  return a + b

add = lambda a, b : a + b # 2 번 방식

(lambda a, b : a + b)(3, 4)# 3 번 방식
# Out:
# 7

# %%
a= [1,2,3,4]

def func(x):
  return x *2+1

func = lambda x: x*2+1

b = [func(v) for v in a]

list(map(lambda x : x*2+1, a)) #list에 넣어야 결과값이 묶여서 나옴
# Out:
# [3, 5, 7, 9]

# %%
a = ['Alex', 'Peter', '귀도', '서동관', '홍준표']

# %%
a = [30,40,60, 20,70]
b = ['김', '이', '박', '홍', '서']

c= sorted(zip(a, b))
c
# Out:
# [(20, '홍'), (30, '김'), (40, '이'), (60, '박'), (70, '서')]

# %%
d= [c[i][1] for i in range(5)]
print(d)

list(map(lambda x: c[x][1], range(0,5)))
# Out:
# ['홍', '김', '이', '박', '서']
# ['홍', '김', '이', '박', '서']

# %%
d= []

for item in c:
  d.append(item[1])

d = [name for score, name in c]
d

list(map(lambda item: item[1], c))
# Out:
# ['홍', '김', '이', '박', '서']

# %%
list(zip(*c))[1] # 리스트가 벗겨짐 (*c)
# Out:
# ('홍', '김', '이', '박', '서')

# %%
list(zip(*c))
# Out:
# [(20, 30, 40, 60, 70), ('홍', '김', '이', '박', '서')]

# %%
data =[ {'name': '김', 'math': 80},
      {'name': '이', 'math': 30},
      {'name': '박', 'math': 60},
      {'name': '홍', 'math': 20},
      {'name': '서', 'math': 70}]

def func(a):
  return (a['math'], a['name'])

data2= sorted(map(func, data))
list(data2)
# Out:
# [(20, '홍'), (30, '이'), (60, '박'), (70, '서'), (80, '김')]

# %%
list(zip(*data2))
# Out:
# [(20, 30, 60, 70, 80), ('홍', '이', '박', '서', '김')]

# %%
sorted(data, key=lambda x: x['math']) # key에는 함수를 사용해서 쉽게 정렬할 수 있음
# Out:
# [{'name': '홍', 'math': 20},
#  {'name': '이', 'math': 30},
#  {'name': '박', 'math': 60},
#  {'name': '서', 'math': 70},
#  {'name': '김', 'math': 80}]

# %%
import random

correct = random.randint(0,7)
if random.random() < 0.5:
  jewel_weight = 101
else:
  jewel_weight = 99

weights = [ 100 for i in range(8)]
weights[correct] = jewel_weight

weights
# Out:
# [100, 100, 100, 100, 100, 100, 100, 101]

# %%
letters = '123'
def parse(letters):
  result = []
  for letter in letters:
    result.append(int(letter))
  return result

# %%
 for _ in range(3):
  user_str = '123/456'
  l_s, r_s = user_str.split('/')

  left_w=0
  for i in left:
    left_w += weights[i]

  right_w = 0
  for j in right:
    right_w = weights[j]

  if left_w > right_w:
    print(l_s, '>', r_s)
  elif left_w < right_w:
    print(l_s, '<', r_s)

  else:
    print(l_s, '==', r_s)

ans = int(input('정답은?'))

if correct == ans:
  print('정답입니다.')

else:
  print('틀렸습니다.. 정답은 :', correct)
# Out:
# 123 > 456
# 123 > 456
# 123 > 456
# 정답은?5
# 틀렸습니다.. 정답은 : 7

# %%
a= [50,30,60,20,30,10]

total = 0
for v in a:
  total += v

# %%
# Out:
# 0.0
