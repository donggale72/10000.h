# %% [markdown]
# #BaggingRegressor & 교차 검정

# %%
import pandas as pd
car = pd.read_csv('/content/drive/MyDrive/datasets/CarPrice_Assignment.csv')

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        205 non-null    int64
#  1   car_ID            205 non-null    int64
#  2   symboling         205 non-null    int64
#  3   CarName           205 non-null    object
#  4   fueltype          205 non-null    object
#  5   aspiration        205 non-null    object
#  6   doornumber        205 non-null    object
#  7   carbody           205 non-null    object
#  8   drivewheel        205 non-null    object
#  9   enginelocation    205 non-null    object
#  10  wheelbase         205 non-null    float64
#  11  carlength         205 non-null    float64
#  12  carwidth          205 non-null    float64
#  13  carheight         205 non-null    float64
#  14  curbweight        205 non-null    int64
#  15  enginetype        205 non-null    object
# ...

# %%
car_num = car.select_dtypes(['number']) #DataFrame에서 숫자형 데이터만 포함하는 새로운 DataFrame을 생성하는 코드
# 자료형이 number 인 변수 선택, include=['number'], 자료형이 명목형인 경우 변수 선택 exclude = ['object']

# %%
feature = list(car_num.columns.difference(['price', 'car_ID']))
x = car[feature]
y = car_num['price']
x.shape, y.shape
# Out:
# ((205, 15), (205,))

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        205 non-null    int64
#  1   boreratio         205 non-null    float64
#  2   carheight         205 non-null    float64
#  3   carlength         205 non-null    float64
#  4   carwidth          205 non-null    float64
#  5   citympg           205 non-null    int64
#  6   compressionratio  205 non-null    float64
#  7   curbweight        205 non-null    int64
#  8   enginesize        205 non-null    int64
#  9   highwaympg        205 non-null    int64
#  10  horsepower        205 non-null    int64
#  11  peakrpm           205 non-null    int64
#  12  stroke            205 non-null    float64
#  13  symboling         205 non-null    int64
#  14  wheelbase         205 non-null    float64
# dtypes: float64(7), int64(8)
# memory usage: 24.1 KB

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
reg = BaggingRegressor(base_estimator = DecisionTreeRegressor(), oob_score = True)
reg = reg.fit(x, y)
reg.oob_score_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_bagging.py:1253: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# 0.8721852996583241

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score

# BaggingRegressor 정의 (DecisionTreeRegressor를 기본 추정기로 사용)
bagging_regressor = BaggingRegressor(base_estimator=DecisionTreeRegressor(), oob_score=True)

# 교차 검증 수행 (예: 5-겹 교차 검증)
cv_scores = cross_val_score(bagging_regressor, x, y, cv=5)

print(cv_scores)
print(np.mean(cv_scores)) #결론적으로, 교차 검증을 통해 얻은 결과가 일반적으로 더 신뢰할 수 있으며 모델의 일반화 능력을 더 잘 반영한다고 볼 수 있음
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_bagging.py:1253: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_bagging.py:1253: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# ...
